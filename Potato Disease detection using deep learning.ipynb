# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS=3
EPOCHS = 30

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/PlantVillage",
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size = 32
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset)
# Out:
# 68

# %%
plt.figure(figsize = (10,10))
for image_batch, label_batch in dataset.take(1):
  for i in range(12):
    ax = plt.subplot(3,4,i+1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 54.400000000000006

# %%
train_ds = dataset.take(54)
len(train_ds)
# Out:
# 54

# %%
test_ds = dataset.skip(54)
len(test_ds)
# Out:
# 14

# %%
val_size = 0.1
len(dataset)*val_size
# Out:
# 6.800000000000001

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 8

# %%
def get_dataset_partitions_tf(ds, train_split=0.8,val_split=0.1,test_split=0.1,shuffle=True,shuffle_size=10000):

  ds_size = len(ds)

  if shuffle:
    ds = ds.shuffle(shuffle_size, seed = 12)
  train_size = int(train_split * ds_size)
  val_size = int(val_split * ds_size)

  train_ds = ds.take(train_size)
  val_ds = ds.skip(train_size).take(val_size)

  test_ds = ds.skip(train_size).skip(val_size)


  return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 54

# %%
len(val_ds)
# Out:
# 6

# %%
len(test_ds)
# Out:
# 8

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
input_shape = (BATCH_SIZE,IMAGE_SIZE, IMAGE_SIZE,CHANNELS)
n_classes = 3
model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32,(3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64,(3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64,(3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64,(3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64,(3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPool2D((2,2)),
    layers.Flatten(),
    layers.Dense(64, activation = 'relu'),
    layers.Dense(n_classes, activation = 'softmax'),
])

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2  (32, 127, 127, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (32, 62, 62, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 64)          36928
#
#  max_pooling2d_2 (MaxPoolin  (32, 30, 30, 64)          0
#  g2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 64)          36928
#
#  max_pooling2d_3 (MaxPoolin  (32, 14, 14, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 64)          36928
#
#  max_pooling2d_4 (MaxPoolin  (32, 6, 6, 64)            0
#  g2D)
#
#  flatten (Flatten)           (32, 2304)                0
#
#  dense (Dense)               (32, 64)                  147520
#
#  dense_1 (Dense)             (32, 3)                   195
#
# =================================================================
# Total params: 277891 (1.06 MB)
# Trainable params: 277891 (1.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ['accuracy']
)

# %%
history = model.fit(
    train_ds,
    epochs = EPOCHS,
    batch_size = BATCH_SIZE,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/30
# 54/54 [==============================] - 298s 160ms/step - loss: 0.8933 - accuracy: 0.5243 - val_loss: 0.7339 - val_accuracy: 0.6094
# Epoch 2/30
# 54/54 [==============================] - 3s 64ms/step - loss: 0.6004 - accuracy: 0.7517 - val_loss: 0.5690 - val_accuracy: 0.7656
# Epoch 3/30
# 54/54 [==============================] - 3s 63ms/step - loss: 0.3550 - accuracy: 0.8594 - val_loss: 0.2140 - val_accuracy: 0.9219
# Epoch 4/30
# 54/54 [==============================] - 3s 64ms/step - loss: 0.2213 - accuracy: 0.9201 - val_loss: 0.1705 - val_accuracy: 0.9427
# Epoch 5/30
# 54/54 [==============================] - 4s 67ms/step - loss: 0.1645 - accuracy: 0.9363 - val_loss: 0.6153 - val_accuracy: 0.7865
# Epoch 6/30
# 54/54 [==============================] - 3s 63ms/step - loss: 0.1211 - accuracy: 0.9502 - val_loss: 0.1510 - val_accuracy: 0.9583
# Epoch 7/30
# 54/54 [==============================] - 3s 64ms/step - loss: 0.1436 - accuracy: 0.9450 - val_loss: 0.1638 - val_accuracy: 0.9479
# Epoch 8/30
# 54/54 [==============================] - 4s 67ms/step - loss: 0.1213 - accuracy: 0.9543 - val_loss: 0.1257 - val_accuracy: 0.9531
# Epoch 9/30
# 54/54 [==============================] - 3s 64ms/step - loss: 0.1614 - accuracy: 0.9334 - val_loss: 0.5519 - val_accuracy: 0.7708
# Epoch 10/30
# 54/54 [==============================] - 3s 64ms/step - loss: 0.1013 - accuracy: 0.9583 - val_loss: 0.1322 - val_accuracy: 0.9635
# Epoch 11/30
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0803 - accuracy: 0.9682 - val_loss: 0.1356 - val_accuracy: 0.9531
# Epoch 12/30
# 54/54 [==============================] - 4s 67ms/step - loss: 0.1307 - accuracy: 0.9566 - val_loss: 0.1669 - val_accuracy: 0.9479
# Epoch 13/30
# 54/54 [==============================] - 3s 63ms/step - loss: 0.0777 - accuracy: 0.9688 - val_loss: 0.1189 - val_accuracy: 0.9688
# Epoch 14/30
# 54/54 [==============================] - 3s 63ms/step - loss: 0.0852 - accuracy: 0.9670 - val_loss: 0.2060 - val_accuracy: 0.9271
# Epoch 15/30
# 54/54 [==============================] - 3s 63ms/step - loss: 0.0790 - accuracy: 0.9728 - val_loss: 0.1290 - val_accuracy: 0.9635
# Epoch 16/30
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0939 - accuracy: 0.9653 - val_loss: 0.4263 - val_accuracy: 0.8542
# Epoch 17/30
# 54/54 [==============================] - 3s 62ms/step - loss: 0.0845 - accuracy: 0.9699 - val_loss: 0.1021 - val_accuracy: 0.9740
# Epoch 18/30
# 54/54 [==============================] - 3s 62ms/step - loss: 0.0599 - accuracy: 0.9803 - val_loss: 0.1104 - val_accuracy: 0.9583
# Epoch 19/30
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0593 - accuracy: 0.9757 - val_loss: 0.3333 - val_accuracy: 0.8906
# Epoch 20/30
# 54/54 [==============================] - 3s 65ms/step - loss: 0.0622 - accuracy: 0.9751 - val_loss: 0.1868 - val_accuracy: 0.9375
# Epoch 21/30
# 54/54 [==============================] - 3s 62ms/step - loss: 0.0470 - accuracy: 0.9844 - val_loss: 0.1238 - val_accuracy: 0.9688
# Epoch 22/30
# 54/54 [==============================] - 3s 62ms/step - loss: 0.0480 - accuracy: 0.9850 - val_loss: 0.2247 - val_accuracy: 0.9115
# Epoch 23/30
# 54/54 [==============================] - 3s 63ms/step - loss: 0.1054 - accuracy: 0.9676 - val_loss: 0.0855 - val_accuracy: 0.9688
# Epoch 24/30
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0555 - accuracy: 0.9803 - val_loss: 0.1695 - val_accuracy: 0.9635
# Epoch 25/30
# 54/54 [==============================] - 3s 63ms/step - loss: 0.0552 - accuracy: 0.9774 - val_loss: 0.2298 - val_accuracy: 0.9271
# Epoch 26/30
# 54/54 [==============================] - 3s 63ms/step - loss: 0.0613 - accuracy: 0.9786 - val_loss: 0.0720 - val_accuracy: 0.9792
# Epoch 27/30
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0531 - accuracy: 0.9838 - val_loss: 0.3467 - val_accuracy: 0.8854
# Epoch 28/30
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0646 - accuracy: 0.9780 - val_loss: 0.1504 - val_accuracy: 0.9635
# Epoch 29/30
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0322 - accuracy: 0.9884 - val_loss: 0.2339 - val_accuracy: 0.9583
# Epoch 30/30
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0622 - accuracy: 0.9751 - val_loss: 0.2390 - val_accuracy: 0.9375

# %%
scores = model.evaluate(test_ds)
# Out:
# 8/8 [==============================] - 4s 28ms/step - loss: 0.2440 - accuracy: 0.9141

# %%
scores
# Out:
# [0.2439917027950287, 0.9140625]

# %%
history

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

  first_image = images_batch[0].numpy().astype('uint8')
  first_label = labels_batch[0].numpy()

  print("first image to predict")
  plt.imshow(first_image)
  plt.axis("off")
  print("actual label:",class_names[first_label])

  batch_prediction = model.predict(images_batch)
  print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Potato___Early_blight
# 1/1 [==============================] - 0s 58ms/step
# predicted label: Potato___Early_blight

# %%
def  predict(model,img):
  img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
  img_array = tf.expand_dims(img_array, 0)

  predictions = model.predict(img_array)

  predicted_class = class_names[np.argmax(predictions[0])]
  confidence = round(100 * (np.max(predictions[0])),2)

  return predicted_class, confidence

# %%
plt.figure(figsize=((15,15)))
for images, labels in test_ds.take(1):
  for i in range(12):
    ax = plt.subplot(3,4,i+1)
    plt.axis("off")
    plt.imshow(images[i].numpy().astype("uint8"))

    predicted_class, confidence = predict(model,images[i].numpy())
    actual_class = class_names[labels[i]]

    plt.title(f"Actual: {actual_class},\n predicted: {predicted_class},\n confidence: {confidence}%")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
model_version=1
model.save(f"/content/drive/MyDrive/PlantVillage/{model_version}")
